# %% [markdown]
# <font size=6>Folium Map 시각화

# %% [markdown]
# * GeoBand :  https://compas.lh.or.kr/api/python#%ED%8C%A8%ED%82%A4%EC%A7%80-%EC%82%AC%EC%9A%A9
# * Folium : https://python-visualization.github.io/folium/index.html
# * Google Console : https://console.cloud.google.com/

# %%
# ! pip install folium
# ! pip install googlemaps

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


sns.set()

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML

display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container{width:100% !important;}</style>

# %%
import folium
from folium import plugins
import re
import googlemaps
import pprint

# %% [markdown]
# # Folium

# %% [markdown]
# ## map

# %% [markdown]
# ## Marker

# %%
map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=14, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a778b1b463369deb9e20721c0a6a5b53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a778b1b463369deb9e20721c0a6a5b53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a778b1b463369deb9e20721c0a6a5b53 = L.map(
#                 &quot;map_a778b1b463369deb9e20721c0a6a5b53&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a4809dda08ca0bfd461452bce981e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tooltip = "클릭시 장소명 보여줄게"

folium.Marker(
    [37.5666805, 126.9784147], 
    popup="<i>시청</i>", 
    tooltip=tooltip,
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a778b1b463369deb9e20721c0a6a5b53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a778b1b463369deb9e20721c0a6a5b53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a778b1b463369deb9e20721c0a6a5b53 = L.map(
#                 &quot;map_a778b1b463369deb9e20721c0a6a5b53&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a4809dda08ca0bfd461452bce981e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var marker_8fa2264bb07c52c21fde9d9b57c5c514 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var icon_9047c9ff82ff6d6d5782e7d519e7f9e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.setIcon(icon_9047c9ff82ff6d6d5782e7d519e7f9e8);
#
#
#         var popup_14ac05b399d74b9df1bc2290f167e02a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7962fe14968f51dd204c228be79afecf = $(`&lt;div id=&quot;html_7962fe14968f51dd204c228be79afecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_14ac05b399d74b9df1bc2290f167e02a.setContent(html_7962fe14968f51dd204c228be79afecf);
#
#
#
#         marker_8fa2264bb07c52c21fde9d9b57c5c514.bindPopup(popup_14ac05b399d74b9df1bc2290f167e02a)
#         ;
#
#
#
#
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 장소명 보여줄게
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import base64

pic = base64.b64encode(open('./static/hotel.png','rb').read()).decode()
image_tag = '<img src="data:image/jpeg;base64,{}">'.format(pic)
iframe = folium.IFrame(image_tag, width=250, height=200)
img_popup = folium.Popup(iframe, max_width=650)

folium.Marker(
    [37.5666805, 126.9784147], 
    popup=img_popup, 
    tooltip="클릭시 이미지보기",
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a778b1b463369deb9e20721c0a6a5b53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a778b1b463369deb9e20721c0a6a5b53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a778b1b463369deb9e20721c0a6a5b53 = L.map(
#                 &quot;map_a778b1b463369deb9e20721c0a6a5b53&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a4809dda08ca0bfd461452bce981e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var marker_8fa2264bb07c52c21fde9d9b57c5c514 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var icon_9047c9ff82ff6d6d5782e7d519e7f9e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.setIcon(icon_9047c9ff82ff6d6d5782e7d519e7f9e8);
#
#
#         var popup_14ac05b399d74b9df1bc2290f167e02a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7962fe14968f51dd204c228be79afecf = $(`&lt;div id=&quot;html_7962fe14968f51dd204c228be79afecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_14ac05b399d74b9df1bc2290f167e02a.setContent(html_7962fe14968f51dd204c228be79afecf);
#
#
#
#         marker_8fa2264bb07c52c21fde9d9b57c5c514.bindPopup(popup_14ac05b399d74b9df1bc2290f167e02a)
#         ;
#
#
#
#
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 장소명 보여줄게
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2bd3dd1b62e5a5c459928ffb007453bf = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var icon_2817baf044e768c9d9f0eefc2d48a74a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bd3dd1b62e5a5c459928ffb007453bf.setIcon(icon_2817baf044e768c9d9f0eefc2d48a74a);
#
#
#         var popup_e0132689e290f5e8c2c097b438f08ea3 = L.popup({&quot;maxWidth&quot;: 650});
#
#
#
#                 var i_frame_ed9f67581fe979c3bac16093989f30dd = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;250&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_e0132689e290f5e8c2c097b438f08ea3.setContent(i_frame_ed9f67581fe979c3bac16093989f30dd);
#
#
#
#         marker_2bd3dd1b62e5a5c459928ffb007453bf.bindPopup(popup_e0132689e290f5e8c2c097b438f08ea3)
#         ;
#
#
#
#
#             marker_2bd3dd1b62e5a5c459928ffb007453bf.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 이미지보기
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## CircleMarker

# %%
folium.CircleMarker(
    location= [37.5666805, 126.9784147], 
    radius=100,
    popup="<i>시청</i>", 
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a778b1b463369deb9e20721c0a6a5b53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a778b1b463369deb9e20721c0a6a5b53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a778b1b463369deb9e20721c0a6a5b53 = L.map(
#                 &quot;map_a778b1b463369deb9e20721c0a6a5b53&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a4809dda08ca0bfd461452bce981e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var marker_8fa2264bb07c52c21fde9d9b57c5c514 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var icon_9047c9ff82ff6d6d5782e7d519e7f9e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.setIcon(icon_9047c9ff82ff6d6d5782e7d519e7f9e8);
#
#
#         var popup_14ac05b399d74b9df1bc2290f167e02a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7962fe14968f51dd204c228be79afecf = $(`&lt;div id=&quot;html_7962fe14968f51dd204c228be79afecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_14ac05b399d74b9df1bc2290f167e02a.setContent(html_7962fe14968f51dd204c228be79afecf);
#
#
#
#         marker_8fa2264bb07c52c21fde9d9b57c5c514.bindPopup(popup_14ac05b399d74b9df1bc2290f167e02a)
#         ;
#
#
#
#
#             marker_8fa2264bb07c52c21fde9d9b57c5c514.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 장소명 보여줄게
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2bd3dd1b62e5a5c459928ffb007453bf = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#             var icon_2817baf044e768c9d9f0eefc2d48a74a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bd3dd1b62e5a5c459928ffb007453bf.setIcon(icon_2817baf044e768c9d9f0eefc2d48a74a);
#
#
#         var popup_e0132689e290f5e8c2c097b438f08ea3 = L.popup({&quot;maxWidth&quot;: 650});
#
#
#
#                 var i_frame_ed9f67581fe979c3bac16093989f30dd = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;250&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_e0132689e290f5e8c2c097b438f08ea3.setContent(i_frame_ed9f67581fe979c3bac16093989f30dd);
#
#
#
#         marker_2bd3dd1b62e5a5c459928ffb007453bf.bindPopup(popup_e0132689e290f5e8c2c097b438f08ea3)
#         ;
#
#
#
#
#             marker_2bd3dd1b62e5a5c459928ffb007453bf.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 이미지보기
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_cb38751153eb7e4e1bad8be112bce7e4 = L.circleMarker(
#                 [37.5666805, 126.9784147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a778b1b463369deb9e20721c0a6a5b53);
#
#
#         var popup_e45239349179445cfc7428f00c096a4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0926434c70981a0432fde11381a8eb51 = $(`&lt;div id=&quot;html_0926434c70981a0432fde11381a8eb51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_e45239349179445cfc7428f00c096a4f.setContent(html_0926434c70981a0432f

# %% [markdown]
# ## MarkerCluster

# %%
from folium import plugins
# from folium.plugins import MarkerCluster

# %%
N = 50
lat_list = np.random.uniform(low=36, high=38, size=N)
lng_list = np.random.uniform(low=127, high=129, size=N)

geo_list = []
for i, lat in enumerate(lat_list):
    geo_list.append(  (lat_list[i], lng_list[i])  )

geo_list[:5]   

name_list = []
for i in range(N):
    name_list.append(  "빵집"+str(i)  )

    
map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=6, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
plugins.MarkerCluster(geo_list, popups=name_list).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0016ad837903bf4faa88c6e7241e138f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0016ad837903bf4faa88c6e7241e138f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0016ad837903bf4faa88c6e7241e138f = L.map(
#                 &quot;map_0016ad837903bf4faa88c6e7241e138f&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85b4e8aba012d06ae505b2963b3070f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0016ad837903bf4faa88c6e7241e138f);
#
#
#             var marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd = L.markerClusterGroup(
#                 {}
#             );
#             map_0016ad837903bf4faa88c6e7241e138f.addLayer(marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd);
#
#
#             var marker_0c95fb09c7f4023fc3587bfb5898122f = L.marker(
#                 [37.63967530106855, 127.8136326327388],
#                 {}
#             ).addTo(marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd);
#
#
#         var popup_e0dc1b04e50bd8ec479c1341eaccf4b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a807303277a609bcc7a2707fa142e75 = $(`&lt;div id=&quot;html_7a807303277a609bcc7a2707fa142e75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집0&lt;/div&gt;`)[0];
#                 popup_e0dc1b04e50bd8ec479c1341eaccf4b5.setContent(html_7a807303277a609bcc7a2707fa142e75);
#
#
#
#         marker_0c95fb09c7f4023fc3587bfb5898122f.bindPopup(popup_e0dc1b04e50bd8ec479c1341eaccf4b5)
#         ;
#
#
#
#
#             var marker_694db7e53fc82e42c349303a387124a2 = L.marker(
#                 [37.46658227579841, 127.03153664015748],
#                 {}
#             ).addTo(marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd);
#
#
#         var popup_bc864fbbda8a0b5d3f4c18910928538f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_988e914f5df13ee6a9fe9480da5a6ec7 = $(`&lt;div id=&quot;html_988e914f5df13ee6a9fe9480da5a6ec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집1&lt;/div&gt;`)[0];
#                 popup_bc864fbbda8a0b5d3f4c18910928538f.setContent(html_988e914f5df13ee6a9fe9480da5a6ec7);
#
#
#
#         marker_694db7e53fc82e42c349303a387124a2.bindPopup(popup_bc864fbbda8a0b5d3f4c18910928538f)
#         ;
#
#
#
#
#             var marker_dcd778b9782646610e373ad88fd69a8b = L.marker(
#                 [37.34988548671103, 128.67723240658356],
#                 {}
#             ).addTo(marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd);
#
#
#         var popup_be75776ffc7f37dd6d8a1bc7a499b97a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a35e3489ec26eaf8e8aea03ed5ffc4d5 = $(`&lt;div id=&quot;html_a35e3489ec26eaf8e8aea03ed5ffc4d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집2&lt;/div&gt;`)[0];
#                 popup_be75776ffc7f37dd6d8a1bc7a499b97a.setContent(html_a35e3489ec26eaf8e8aea03ed5ffc4d5);
#
#
#
#         marker_dcd778b9782646610e373ad88fd69a8b.bindPopup(popup_be75776ffc7f37dd6d8a1bc7a499b97a)
#         ;
#
#
#
#
#             var marker_9748041ae170d14053a050e46bf27cc8 = L.marker(
#                 [36.68364059874943, 127.45248808847525],
#                 {}
#             ).addTo(marker_cluster_2b38e0bfddd25df4fecc01c53d8da5bd);
#
#
#         var popup_7d8a8ae53af666a38ff006db4b351662 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fabee4f53c84af0c4a2053f63ba2e8b = $(`&lt;div id=&quot;html_5fabee4f53c84af0c4a2053f63ba2e8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집3&lt;/div&gt;`)[0];
#                 popup_7d8a8ae53af666a38ff006db4b351662.setContent(html_5fabee4f53c84af0c4a2053f63ba2e8b);
#
#
#
#         marker_9748041ae170d14053a050e46bf27cc8.bindPopup(popup_7d8a8ae53af666a38ff006db4b351662)
#         ;
#
#
#
#
#             var marker_a86615870bf83aa2724c070d5dbf6762 = L.marker(
#                 [37.234975795016844, 127.13971045132531],
#                 {}

# %%
from folium.plugins import MarkerCluster

us_map = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(us_map)
folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_989e0ad90cb634685a609b7554f6c44a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_989e0ad90cb634685a609b7554f6c44a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_989e0ad90cb634685a609b7554f6c44a = L.map(
#                 &quot;map_989e0ad90cb634685a609b7554f6c44a&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bddf8571705820b7d76c8642376d05e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_989e0ad90cb634685a609b7554f6c44a);
#
#
#             var marker_cluster_a91a04e0e3548c100e762edd7f2c436d = L.markerClusterGroup(
#                 {}
#             );
#             map_989e0ad90cb634685a609b7554f6c44a.addLayer(marker_cluster_a91a04e0e3548c100e762edd7f2c436d);
#
#
#             var marker_efd693d4f847fef785f35af5d8a4fa8a = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a91a04e0e3548c100e762edd7f2c436d);
#
#
#             var icon_cedee01ad56922f2feaaad6620571f4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_efd693d4f847fef785f35af5d8a4fa8a.setIcon(icon_cedee01ad56922f2feaaad6620571f4c);
#
#
#         var popup_0c56540e73b40384087d8c9d345a7af6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a6f05c20036af7ed2cd7ac4b25386ec = $(`&lt;div id=&quot;html_4a6f05c20036af7ed2cd7ac4b25386ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0c56540e73b40384087d8c9d345a7af6.setContent(html_4a6f05c20036af7ed2cd7ac4b25386ec);
#
#
#
#         marker_efd693d4f847fef785f35af5d8a4fa8a.bindPopup(popup_0c56540e73b40384087d8c9d345a7af6)
#         ;
#
#
#
#
#             var marker_1a8a3612a787115b4ddb8d792aeb339c = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a91a04e0e3548c100e762edd7f2c436d);
#
#
#             var icon_22ed57f4e09c6758f8e569d50e22436d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1a8a3612a787115b4ddb8d792aeb339c.setIcon(icon_22ed57f4e09c6758f8e569d50e22436d);
#
#
#         var popup_c5049cc2a86954b7cc24819058625151 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d2b3cff35da639685825a448a6601b3 = $(`&lt;div id=&quot;html_8d2b3cff35da639685825a448a6601b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c5049cc2a86954b7cc24819058625151.setContent(html_8d2b3cff35da639685825a448a6601b3);
#
#
#
#         marker_1a8a3612a787115b4ddb8d792aeb339c.bindPopup(popup_c5049cc2a86954b7cc24819058625151)
#         ;
#
#
#
#
#             var marker_f23dd36283b80c0a8480e21589eea425 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_a91a04e0e3548c100e762edd7f2c436d);
#
#
#         var popup_d8e597bc828174c1c793c3c969202769 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa3b6a86d80ccf084b16914ae7d5c2fa = $(`&lt;div id=&quot;html_aa3b6a86d80ccf084b16914ae7d5c2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d8e597bc828174c1c793c3c969202769.setContent(html_aa3b6a86d80ccf084b16914ae7d5c2fa);
#
#
#
#         marker_f23dd36283b80c0a8480e21589eea425.bindPopup(popup_d8e597bc828174c1c793c3c969202769)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !importa

# %% [markdown]
# # googlemap

# %%
gmaps = googlemaps.Client(key='AIzaSyCQWM6dFymuis1oh9DelTIPFO1igh1nVuo')

# %% [markdown]
# ## 주소 --> 위/경도
# * <font color=red><b> geocode("지명")

# %%
geocode_result = gmaps.geocode(('제주국제공항'), language='ko')
pprint.pprint(geocode_result)
# print(geocode_result)
# Out:
# [{'address_components': [{'long_name': '제주국제공항',
#                           'short_name': '제주국제공항',
#                           'types': ['airport',
#                                     'establishment',
#                                     'point_of_interest']},
#                          {'long_name': '2',
#                           'short_name': '2',
#                           'types': ['street_number']},
#                          {'long_name': '공항로',
#                           'short_name': '공항로',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_4']},
#                          {'long_name': '제주시',
#                           'short_name': '제주시',
#                           'types': ['locality', 'political']},
#                          {'long_name': '제주특별자치도',
#                           'short_name': '제주특별자치도',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': '대한민국',
#                           'short_name': 'KR',
#                           'types': ['country', 'political']}],
#   'formatted_address': '대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)',
#   'geometry': {'location': {'lat': 33.51041350000001, 'lng': 126.4913534},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 33.51041350000001,
#                                           'lng': 126.4955668},
#                             'southwest': {'lat': 33.5059251,
#                                           'lng': 126.4913534}}},
#   'partial_match': True,
#   'place_id': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#   'plus_code': {'compound_code': '', 'global_code': '8Q58GF6R+5G'},
#   'types': ['airport', 'establishment', 'point_of_interest']}]

# %%
addr = geocode_result[0]['formatted_address']
lat  = geocode_result[0]['geometry']['location']['lat']
lang = geocode_result[0]['geometry']['location']['lng']

print("주소",addr)
print("위도",lat)
print("경도",lang)
# Out:
# 주소 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)
# 위도 33.51041350000001
# 경도 126.4913534

# %% [markdown]
# ## 위/경도 --> 주소
# * <font color=red><b>reverse_geocode((위도, 경도))

# %%
rg_res = gmaps.reverse_geocode( (33.51041350000001,126.4913534), language="ko")
type(rg_res), len(rg_res)
# Out:
# (list, 9)

# %%
rg_res[0]
# Out:
# {'address_components': [{'long_name': '제주국제공항',
#    'short_name': '제주국제공항',
#    'types': ['airport', 'establishment', 'point_of_interest']},
#   {'long_name': '2', 'short_name': '2', 'types': ['street_number']},
#   {'long_name': '공항로',
#    'short_name': '공항로',
#    'types': ['political', 'sublocality', 'sublocality_level_4']},
#   {'long_name': '제주시',
#    'short_name': '제주시',
#    'types': ['locality', 'political']},
#   {'long_name': '제주특별자치도',
#    'short_name': '제주특별자치도',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국',
#    'short_name': 'KR',
#    'types': ['country', 'political']}],
#  'formatted_address': '대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)',
#  'geometry': {'location': {'lat': 33.51041350000001, 'lng': 126.4913534},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 33.51176248029151,
#     'lng': 126.4927023802915},
#    'southwest': {'lat': 33.50906451970851, 'lng': 126.4900044197085}}},
#  'place_id': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#  'plus_code': {'global_code': '8Q58GF6R+5G'},
#  'types': ['airport', 'establishment', 'point_of_interest']}

# %%
for i in range(len(rg_res)) :
    addr = rg_res[i]['formatted_address'] 
    lat  = rg_res[i]['geometry']['location']['lat']
    lng  = rg_res[i]['geometry']['location']['lng']
    print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 8Q58GF6R+5G 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769
# 대한민국 제주특별자치도 제주시 33.4996213 126.5311884
# 대한민국 제주특별자치도 33.4890113 126.4983023
# 대한민국 35.907757 127.766922

# %%
for i in range(len(rg_res)):
    addr = rg_res[i]['formatted_address']
    check = re.match('대한민국[\w\s]*', addr)
    d_addr = len(addr.split())
    if check and d_addr > 3:
        lat  = rg_res[i]['geometry']['location']['lat']
        lng  = rg_res[i]['geometry']['location']['lng']
        print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769

# %% [markdown]
# # GeoJSON

# %% [markdown]
# ## choropleth()

# %%
# ! pip install geopandas

# %%
import geopandas as gpd
import folium
from folium import plugins

# %% [markdown]
# * [대한민국 지역구 GeoJSON]
#     * https://sgis.kostat.go.kr/view/index
#     * https://github.com/raqoon886/Local_HangJeongDong

# %%
state_geo = gpd.read_file('./datasets/seoul_geo_sigugun.json')
state_geo.head(2)
# Out:
#     code name     name_eng base_year  \
# 0  11250  강동구  Gangdong-gu      2013
# 1  11240  송파구    Songpa-gu      2013
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              geometry
# 0                                                                                                                                                                                                                                                                                          POLYGON ((127.11520 37.55753, 127.11880 37.55722, 127.12147 37.55986, 127.12435 37.56144, 127.13594 37.56565, 127.14931 37.56892, 127.15511 37.57094, 127.16683 37.57672, 127.17039 37.57647, 127.17607 37.57679, 127.17906 37.57791, 127.17748 37.57449, 127.17818 37.57148, 127.17995 37.56931, 127.18123 37.56636, 127.18169 37.56286, 127.18409 37.55814, 127.18351 37.55005, 127.18526 37.54889, 127.18481 37.54530, 127.18543 37.54261, 127.18365 37.54241, 127.18116 37.54384, 127.17771 37.54241, 127.17444 37.54278, 127.16830 37.54145, 127.16531 37.54222, 127.15567 37.53120, 127.15538 37.52653, 127.15154 37.52283, 127.14982 37.51927, 127.14792 37.51919, 127.14685 37.51661, 127.14673 37.51416, 127.14532 37.51464, 127.12123 37.52528, 127.12251 37.52752, 127.12532 37.53573, 127.12061 37.53813, 127.11168 37.54067, 127.11418 37.54475, 127.11600 37.55053, 127.11601 37.55580, 127.11520 37.55753))
# 1  POLYGON ((127.06907 37.52228, 127.07496 37.52091, 127.07969 37.52077, 127.08639 37.52162, 127.09436 37.52398, 127.10088 37.52484, 127.10484 37.53120, 127.11168 37.54067, 127.12061 37.53813, 127.12532 37.53573, 127.12251 37.52752, 127.12123 37.52528, 127.14532 37.51464, 127.14673 37.51416, 127.14670 37.51279, 127.14463 37.51153, 127.14324 37.50952, 127.14209 37.50579, 127.14325 37.50265, 127.14735 37.50070, 127.14980 37.50047, 127.15224 37.50170, 127.15401 37.50035, 127.16086 37.49887, 127.16349 37.49745, 127.16200 37.49403, 127.16216 37.49164, 127.16040 37.48778, 127.15892 37.48613, 127.15393 37.48484, 127.15148 37.47745, 127.15150 37.47563, 127.14858 37.47381, 127.14416 37.47369, 127.14112 37.47060, 127.13632 37.47215, 127.13282 37.47257, 127.13307 37.46891, 127.13751 37.46647, 127.13478 37.46510, 127.13084 37.46510, 127.12729 37.46673, 127.12730 37.46422, 127.12441 37.46240, 127.12441 37.46443, 127.12265 37.46757, 127.11381 37.47963, 127.11439 37.48073, 127.11117 37.48571, 127.10779 37.48861, 127.10433 37.49073, 127.09885 37.49303, 127.08050 37.49783, 127.07648 37.49861, 127.07191 37.50224, 127.06927 37.51718, 127.06860 37.51813, 127.06907 37.52228))

# %% [markdown]
# * [서울시 열린데이터 광장] 주민등록인구수
#     * https://data.seoul.go.kr/dataList/419/S/2/datasetView.do

# %%
seoul_ingu = pd.read_csv("./datasets/주민등록인구_20230222161234.csv", sep='\t', encoding='cp949')
seoul_ingu.head(2)
# Out:
#     동별    세대수      총계  세대당인구
# 0  종로구  72797  151999   1.95
# 1   중구  63300  130764   1.91

# %%
seoul_ingu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   동별      25 non-null     object
#  1   세대수     25 non-null     int64
#  2   총계      25 non-null     int64
#  3   세대당인구   25 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 928.0+ bytes

# %%
# Initialize the map:
map = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)

map.choropleth(
    geo_data=state_geo,
    name='인구밀도',
    
    data=seoul_ingu,
    columns=['동별', '총계'],
    
    key_on='feature.properties.name',
    fill_color=  'Blues' if state_geo["code"].str == '11250' else 'Reds',      # 'Blues',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'income'
)


plugins.MousePosition().add_to(map)

# # Save to html
# # m.save('kr_incode.html')
# # webbrowser.open_new("folium_kr.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c902ddcdd0f2d9985bc21b6f2684e89c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c902ddcdd0f2d9985bc21b6f2684e89c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c902ddcdd0f2d9985bc21b6f2684e89c = L.map(
#                 &quot;map_c902ddcdd0f2d9985bc21b6f2684e89c&quot;,
#                 {
#                     center: [37.562225, 126.978555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_243da7c5f5a6499856e7ede7ef6a47fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c902ddcdd0f2d9985bc21b6f2684e89c);
#
#
#             var choropleth_aeb2762a9d8aa2f5800cf53f44bcd0c7 = L.featureGroup(
#                 {}
#             ).addTo(map_c902ddcdd0f2d9985bc21b6f2684e89c);
#
#
#         function geo_json_a56eff600ca070699e6de15fad9fdb57_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;3&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;13&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;9&quot;: case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#de2d26&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;16&quot;: case &quot;21&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;23&quot;: case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc9272&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a56eff600ca070699e6de15fad9fdb57_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a56eff600ca070699e6de15fad9fdb57 = L.geoJson(null, {
#                 onEachFeature: geo_json_a56eff600ca070699e6de15fad9fdb57_onEachFeature,
#
#                 style: geo_json_a56eff600ca070699e6de15fad9fdb57_styler,
#         });
#
#         function geo_json_a56eff600ca070699e6de15fad9fdb57_add (data) {
#             geo_json_a56eff600ca070699e6de15fad9fdb57
#                 .addData(data)
#                 .addTo(choropleth_aeb2762a9d8aa2f5800cf53f44bcd0c7);
#         }
#             geo_json_a56eff600ca070699e6de15fad9fdb57_add({&quot;bbox&quot;: [126.76700465024426, 37.42574929824175, 127.18543378919821, 37.698589417759045], &quot;features&quot;: [{&quot;bbox&quot;: [127.1116764203608, 37.51415680680291, 127.18543378919821, 37.57791388161732], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.1

# %% [markdown]
# ## GeoJson()

# %%
import json
with open('./datasets/seoul_geo_sigugun.json',mode='rt',encoding='utf-8') as f:
    geo = json.loads(f.read())
    f.close()

map = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)
    
folium.GeoJson(
    geo,
    name='seoul_municipalities'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7864c7cda2f84a9509a6364975678c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7864c7cda2f84a9509a6364975678c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7864c7cda2f84a9509a6364975678c13 = L.map(
#                 &quot;map_7864c7cda2f84a9509a6364975678c13&quot;,
#                 {
#                     center: [37.562225, 126.978555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_939d5f00387a70cd2bdc8a356a724bf5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7864c7cda2f84a9509a6364975678c13);
#
#
#
#         function geo_json_8cc492a9c5b83686fba2f5adc67e6159_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8cc492a9c5b83686fba2f5adc67e6159 = L.geoJson(null, {
#                 onEachFeature: geo_json_8cc492a9c5b83686fba2f5adc67e6159_onEachFeature,
#
#         });
#
#         function geo_json_8cc492a9c5b83686fba2f5adc67e6159_add (data) {
#             geo_json_8cc492a9c5b83686fba2f5adc67e6159
#                 .addData(data)
#                 .addTo(map_7864c7cda2f84a9509a6364975678c13);
#         }
#             geo_json_8cc492a9c5b83686fba2f5adc67e6159_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37.49886565522751], [127.1634944215765, 37.497445406097484], [127.16199885180917, 37.49402577547199], [127.16216448592424, 37.491639601211624], [127.16040295326431, 37.4877818619403], [127.15892216655034, 37.486126922469445], [127.15393282790794, 37.48483891408459], [127.15147990997

# %% [markdown]
# # RestAPI
# * https://www.data.go.kr/data/15049995/fileData.do?recommendDataYn=Y#tab-layer-openapi

# %%
import requests
import json

# %% [markdown]
# ## python json
# <pre>
# * load() <b>loads()</b> : 글자-->dic
# * dump() <b>dumps()</b> : dic -->글자

# %% [markdown]
# <font color=red size=3><b> json.loads() 사용시 :  반드시 더블쿼트 dic 데이터 사용

# %%
dic_str = """[  {"userid":"kim", "userpw":1111}, 
                {"userid":"lee", "userpw":2222}
             ]"""
print(dic_str , type(dic_str))


list_dic = json.loads(dic_str)
print(list_dic, type(list_dic))
print("비번:", list_dic[1]["userpw"])
# Out:
# [  {"userid":"kim", "userpw":1111},
#                 {"userid":"lee", "userpw":2222}
#              ] <class 'str'>
# [{'userid': 'kim', 'userpw': 1111}, {'userid': 'lee', 'userpw': 2222}] <class 'list'>
# 비번: 2222

# %%
list_dic = [{'userid': 'kim', 'userpw': 1111}, 
            {'userid': 'lee', 'userpw': 2222}
           ]
print(list_dic, type(list_dic))

list_dic_string = json.dumps(list_dic)
print(list_dic_string, type(list_dic_string))
# Out:
# [{'userid': 'kim', 'userpw': 1111}, {'userid': 'lee', 'userpw': 2222}] <class 'list'>
# [{"userid": "kim", "userpw": 1111}, {"userid": "lee", "userpw": 2222}] <class 'str'>

# %% [markdown]
# ## RestAPI 호출

# %% [markdown]
# <pre>
# Curl
#
# curl -X GET "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page=1&perPage=10&serviceKey=fr%2B%2FkS%3D%3D"
#
# -H  "accept: application/json"
#
# -H  "Authorization: fr%2B%2FkS3Un%2BS%3D%3D"

# %% [markdown]
# ### 단일 호출

# %%
req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page=1&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
res = requests.get(req_url)
print(res)
print(res.status_code)
print(res.encoding)
print(type(res.text), res.text)
# Out:
# <Response [200]>
# 200
# UTF-8
# <class 'str'> {"currentCount":10,"data":[{"경도":"126.9460835","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4973684","장소ID":289,"장소명":"하고수동해수욕장","장소상세설명":"해안도로를 따라서 자전거 타기","지번주소":"제주특별자치도 제주시 우도면 연평리 2609"},{"경도":"126.4940957","도로명주소":"제주특별자치도 제주시 다호6길 15","등록일시":"2018-05-30","사용여부":"y","수정일시":"2018-05-30","위도":"33.4991412","장소ID":282,"장소명":"공항","장소상세설명":"도착","지번주소":"제주특별자치도 제주시 용담2동 1869-2"},{"경도":"126.4164854","도로명주소":"제주특별자치도 제주시 다호6길 15","등록일시":"2018-05-30","사용여부":"y","수정일시":"2018-05-30","위도":"33.4796117","장소ID":283,"장소명":"애월 해안도로","장소상세설명":"바다를 먹고 달리자","지번주소":"제주특별자치도 제주시 애월읍 하귀1리 709"},{"경도":"126.8071463","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4804255","장소ID":294,"장소명":"비자림","장소상세설명":"ㅇㅇ","지번주소":"제주특별자치도 제주시 구좌읍 평대리 3017"},{"경도":"126.6618011","도로명주소":"제주특별자치도 제주시 남조로 2023 교래자연휴양림","등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4374471","장소ID":292,"장소명":"교래자연휴양림","장소상세설명":"ㄴㄴ","지번주소":"제주특별자치도 제주시 조천읍 교래리 산119"},{"경도":"126.4605029","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4851838","장소ID":293,"장소명":"이호해수욕장","장소상세설명":"ㅇㅇ","지번주소":"제주특별자치도 제주시 노형동 3744-4"},{"경도":"126.8152373","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.3247440","장소ID":295,"장소명":"제주허브동산","장소상세설명":"허브동산","지번주소":"제주특별자치도 서귀포시 표선면 표선리 2530"},{"경도":"126.4907231","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4695392","장소ID":296,"장소명":"한라수목원","장소상세설명":"연동","지번주소":"제주특별자치도 제주시 연동 996-2"},{"경도":"126.7989320","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4612383","장소ID":297,"장소명":"비자림","장소상세설명":"비자림 숲걷기","지번주소":"제주특별자치도 제주시 구좌읍 송당리 산218"},{"경도":"126.6311740","도로명주소":null,"등록일시":"2018-05-31","사용여부":"y","수정일시":"2018-05-31","위도":"33.4243152","장소ID":298,"장소명":"절물자연휴양림","장소상세설명":"장생이 숲길","지번주소":"제주특별자치도 제주시 조천읍 교래리 산137-29"}],"matchCount":3992,"page":1,"perPage":10,"totalCount":3992}

# %%
dic = json.loads(res.text)
dic
# Out:
# {'currentCount': 10,
#  'data': [{'경도': '126.9460835',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4973684',
#    '장소ID': 289,
#    '장소명': '하고수동해수욕장',
#    '장소상세설명': '해안도로를 따라서 자전거 타기',
#    '지번주소': '제주특별자치도 제주시 우도면 연평리 2609'},
#   {'경도': '126.4940957',
#    '도로명주소': '제주특별자치도 제주시 다호6길 15',
#    '등록일시': '2018-05-30',
#    '사용여부': 'y',
#    '수정일시': '2018-05-30',
#    '위도': '33.4991412',
#    '장소ID': 282,
#    '장소명': '공항',
#    '장소상세설명': '도착',
#    '지번주소': '제주특별자치도 제주시 용담2동 1869-2'},
#   {'경도': '126.4164854',
#    '도로명주소': '제주특별자치도 제주시 다호6길 15',
#    '등록일시': '2018-05-30',
#    '사용여부': 'y',
#    '수정일시': '2018-05-30',
#    '위도': '33.4796117',
#    '장소ID': 283,
#    '장소명': '애월 해안도로',
#    '장소상세설명': '바다를 먹고 달리자',
#    '지번주소': '제주특별자치도 제주시 애월읍 하귀1리 709'},
#   {'경도': '126.8071463',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4804255',
#    '장소ID': 294,
#    '장소명': '비자림',
#    '장소상세설명': 'ㅇㅇ',
#    '지번주소': '제주특별자치도 제주시 구좌읍 평대리 3017'},
#   {'경도': '126.6618011',
#    '도로명주소': '제주특별자치도 제주시 남조로 2023 교래자연휴양림',
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4374471',
#    '장소ID': 292,
#    '장소명': '교래자연휴양림',
#    '장소상세설명': 'ㄴㄴ',
#    '지번주소': '제주특별자치도 제주시 조천읍 교래리 산119'},
#   {'경도': '126.4605029',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4851838',
#    '장소ID': 293,
#    '장소명': '이호해수욕장',
#    '장소상세설명': 'ㅇㅇ',
#    '지번주소': '제주특별자치도 제주시 노형동 3744-4'},
#   {'경도': '126.8152373',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.3247440',
#    '장소ID': 295,
#    '장소명': '제주허브동산',
#    '장소상세설명': '허브동산',
#    '지번주소': '제주특별자치도 서귀포시 표선면 표선리 2530'},
#   {'경도': '126.4907231',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4695392',
#    '장소ID': 296,
#    '장소명': '한라수목원',
#    '장소상세설명': '연동',
#    '지번주소': '제주특별자치도 제주시 연동 996-2'},
#   {'경도': '126.7989320',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4612383',
#    '장소ID': 297,
#    '장소명': '비자림',
#    '장소상세설명': '비자림 숲걷기',
#    '지번주소': '제주특별자치도 제주시 구좌읍 송당리 산218'},
#   {'경도': '126.6311740',
#    '도로명주소': None,
#    '등록일시': '2018-05-31',
#    '사용여부': 'y',
#    '수정일시': '2018-05-31',
#    '위도': '33.4243152',
#    '장소ID': 298,
#    '장소명': '절물자연휴양림',
#    '장소상세설명': '장생이 숲길',
#    '지번주소': '제주특별자치도 제주시 조천읍 교래리 산137-29'}],
#  'matchCount': 3992,
#  'page': 1,
#  'perPage': 10,
#  'totalCount': 3992}

# %%
dic = json.loads(res.text)
# pprint.pprint(dic)
# pprint.pprint( dic["data"] )
for d in dic["data"]:
    lng = d["경도"]
    lat = d["위도"]
    sname = d["장소명"]
    print(lng, lat, sname)
# Out:
# 126.9460835 33.4973684 하고수동해수욕장
# 126.4940957 33.4991412 공항
# 126.4164854 33.4796117 애월 해안도로
# 126.8071463 33.4804255 비자림
# 126.6618011 33.4374471 교래자연휴양림
# 126.4605029 33.4851838 이호해수욕장
# 126.8152373 33.3247440 제주허브동산
# 126.4907231 33.4695392 한라수목원
# 126.7989320 33.4612383 비자림
# 126.6311740 33.4243152 절물자연휴양림

# %% [markdown]
# ### 반복 호출

# %%
import time
import math
#------------------------------------------
start = time.time()
math.factorial(100000)
#------------------------------------------

total_len = 0
for i in range(1,3,1):
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    print(res.status_code)
    # print(type(res.text), res.text[:100])
    dic = json.loads(res.text)
    list_dic = dic['data']
    list_len = len(list_dic)
    total_len = total_len + list_len
    time.sleep(1) # 1초만
print("총:",total_len)    

#------------------------------------------
end = time.time()
print(f"{end - start:.5f} sec")
#------------------------------------------
# Out:
# 200
# 200
# 총: 20
# 2.43115 sec

# %% [markdown]
# #### DataFrame = list + dict
# * [{"aa":1, "bb":2},{"aa":22, "bb":33}]

# %%
import time
import math
# #------------------------------------------
# start = time.time()
# math.factorial(100000)
# #------------------------------------------

for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
# print(list_dic)    
df = pd.DataFrame(list_dic)
df = df[['위도','경도','장소명']].copy()
df.head(2)

# #------------------------------------------
# end = time.time()
# print(f"{end - start:.5f} sec")
# #------------------------------------------
# Out:
#            위도           경도        장소명
# 0  33.3807275  126.2296422     협재해수욕장
# 1  33.2354175  126.3669632  용왕난드르향토음식

# %%
import time
import math


temp_list = []
for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
    
    for dic in  list_dic:
        temp_dic = {"위도":dic["위도"], "경도":dic["경도"], "장소명":dic["장소명"]}
        temp_list.append(temp_dic)

#print(temp_list)
# [{'위도': '33.4973684', '경도': '126.9460835', '장소명': '하고'}, 
#  {'위도': '33.4991412', '경도': '126.4940957', '장소명': '공항'}
# ] 
 
df = pd.DataFrame(temp_list)
df.head(2)
# Out:
#            위도           경도       장소명
# 0  33.4973684  126.9460835  하고수동해수욕장
# 1  33.4991412  126.4940957        공항

# %% [markdown]
# #### DataFrame = list + list
# * [[1, 2], [22, 33]]

# %%
import time
import math


temp_list = []
for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
    
    for dic in  list_dic:
        mylist = [dic["위도"],dic["경도"], dic["장소명"]]
        temp_list.append(mylist)

# print(temp_list)
# [['33.4973684', '126.9460835', '하고'], 
#  ['33.4991412', '126.4940957', '공항']
# ]

df = pd.DataFrame(temp_list, columns=["위도","경도","장소명"])
df.head(2)
# Out:
#            위도           경도       장소명
# 0  33.4973684  126.9460835  하고수동해수욕장
# 1  33.4991412  126.4940957        공항

# %%
위도  경도   장소명
--- -----   ------

# %% [markdown]
# <font size=6><b>[실습] 제주 관광명소 GIS 시각화

# %% [markdown]
# # [실습] 제주 관광 GIS 시각화
# * [공공데이터포털] 제주관광공사_제주관광정보시스템(VISIT JEJU)_여행장소
#     * https://www.data.go.kr/data/15049995/fileData.do?recommendDataYn=Y

# %% [markdown]
# ## Data Load

# %%
dataset = pd.read_csv("./datasets/제주관광공사_여행장소_20220322.csv", encoding="cp949")
dataset.head(3)
# Out:
#    장소ID       장소명                도로명주소            장소상세설명         위도  \
# 0   289  하고수동해수욕장                  NaN  해안도로를 따라서 자전거 타기  33.497368
# 1   282        공항  제주특별자치도 제주시 다호6길 15                도착  33.499141
# 2   283   애월 해안도로  제주특별자치도 제주시 다호6길 15        바다를 먹고 달리자  33.479612
#
#            경도        등록일시        수정일시                      지번주소 사용여부
# 0  126.946084  2018-05-31  2018-05-31  제주특별자치도 제주시 우도면 연평리 2609    y
# 1  126.494096  2018-05-30  2018-05-30   제주특별자치도 제주시 용담2동 1869-2    y
# 2  126.416485  2018-05-30  2018-05-30  제주특별자치도 제주시 애월읍 하귀1리 709    y

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3992 entries, 0 to 3991
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   장소ID    3992 non-null   int64
#  1   장소명     3992 non-null   object
#  2   도로명주소   2960 non-null   object
#  3   장소상세설명  3989 non-null   object
#  4   위도      3992 non-null   float64
#  5   경도      3992 non-null   float64
#  6   등록일시    3992 non-null   object
#  7   수정일시    3992 non-null   object
#  8   지번주소    3991 non-null   object
#  9   사용여부    3960 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 312.0+ KB

# %%
df = dataset[dataset['장소상세설명']=='숙소']
df.shape
# Out:
# (240, 10)

# %% [markdown]
# ## Marker

# %%
map = folium.Map(location=[33.51041350000001,126.4913534], zoom_start=10)

geo_list = []
for i in range(len(df))[0:30]  :
    lat = df.iloc[i]['위도']
    lng = df.iloc[i]['경도']
    sname = df.iloc[i]['장소명']
    print(lat, lng, sname)
    geo_list.append( (lat,lng) )
    folium.Marker([lat, lng], popup=sname).add_to(map)
    
map
# Out:
# 33.2519324 126.5097695 비스타케이월드컵
# 33.4482999 126.6376619 제주한화리조트
# 33.2785158 126.5275284 비스타케이호텔
# 33.540343 126.8262234 토끼굴
# 33.5356373 126.8211555 한동올레펜션
# 33.5172018 126.8662067 다락마마(숙소)
# 33.3710021 126.8623183 삼달리 참꽃네(숙소)
# 33.4939429 126.4425896 올레로펜션(숙소)
# 33.4397047 126.3207189 우디하우스
# 33.2674813 126.1990941 몽구네민박
# 33.2470353 126.5668401 퍼스트70호텔
# 33.2470804 126.5668101 더퍼스트70호텔
# 33.3777096 126.2365028 제주청소년수련원
# 33.2562094 126.4129041 꿈에그린펜션
# 33.4577779 126.9001271 제주 아비앙또
# 33.4729021 126.9118857 더포그레이스 (숙소)
# 33.2883509 126.4966179 아이브리조트
# 33.2317496 126.2956207 가라지하우스
# 33.3056538 126.7951466 숙소
# 33.5433127 126.6634124 아이미제주비치호텔
# 33.3826072 126.2253466 네이처트레일
# 33.4336535 126.7379624 일성 리조트
# 33.2327276 126.4890002 켄싱턴 리조트 서귀포
# 33.543277 126.6634385 아이미제주비치호텔
# 33.5280481 126.8739049 숙소
# 33.4578642 126.9002072 제주 아비앙또
# 33.2406451 126.5563615 한국 SGI 제주한일우호연수원
# 33.4933793 126.4912331 호텔시리우스
# 33.3900255 126.8756099 고래의꿈
# 33.449562 126.3057621 예그리나 펜션
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c067fe6e874b6f939b6ea184202628dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c067fe6e874b6f939b6ea184202628dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c067fe6e874b6f939b6ea184202628dd = L.map(
#                 &quot;map_c067fe6e874b6f939b6ea184202628dd&quot;,
#                 {
#                     center: [33.51041350000001, 126.4913534],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b02e860bfa1327528ddfa30814049b7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#             var marker_60ba1f33f33cda494602fe9aa50bafab = L.marker(
#                 [33.2519324, 126.5097695],
#                 {}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#         var popup_b669362b6795718d3446c4d27b9cc3dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd7f3330e80115414af69c09f026ead3 = $(`&lt;div id=&quot;html_cd7f3330e80115414af69c09f026ead3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;비스타케이월드컵&lt;/div&gt;`)[0];
#                 popup_b669362b6795718d3446c4d27b9cc3dd.setContent(html_cd7f3330e80115414af69c09f026ead3);
#
#
#
#         marker_60ba1f33f33cda494602fe9aa50bafab.bindPopup(popup_b669362b6795718d3446c4d27b9cc3dd)
#         ;
#
#
#
#
#             var marker_1c3a763710c68039b3a0b3e69f72a1c5 = L.marker(
#                 [33.4482999, 126.6376619],
#                 {}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#         var popup_6774e31f172f42d992e608c6b7c6e7ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d015b16e3aeac211b05db5cffcafff00 = $(`&lt;div id=&quot;html_d015b16e3aeac211b05db5cffcafff00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주한화리조트&lt;/div&gt;`)[0];
#                 popup_6774e31f172f42d992e608c6b7c6e7ae.setContent(html_d015b16e3aeac211b05db5cffcafff00);
#
#
#
#         marker_1c3a763710c68039b3a0b3e69f72a1c5.bindPopup(popup_6774e31f172f42d992e608c6b7c6e7ae)
#         ;
#
#
#
#
#             var marker_241e509a7890ec5f2155643bfee2d00a = L.marker(
#                 [33.2785158, 126.5275284],
#                 {}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#         var popup_059628c81e725171eed265e7fef57461 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b405edcc9d7b15448ff6200721e90207 = $(`&lt;div id=&quot;html_b405edcc9d7b15448ff6200721e90207&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;비스타케이호텔&lt;/div&gt;`)[0];
#                 popup_059628c81e725171eed265e7fef57461.setContent(html_b405edcc9d7b15448ff6200721e90207);
#
#
#
#         marker_241e509a7890ec5f2155643bfee2d00a.bindPopup(popup_059628c81e725171eed265e7fef57461)
#         ;
#
#
#
#
#             var marker_3b779b3ecc24e4a2e55541e876b2f33b = L.marker(
#                 [33.540343, 126.8262234],
#                 {}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#         var popup_cfa056fea95d3c71005b11f4ee687b53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d844e6cb1c23f141269e47c489f62aa = $(`&lt;div id=&quot;html_7d844e6cb1c23f141269e47c489f62aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;토끼굴 &lt;/div&gt;`)[0];
#                 popup_cfa056fea95d3c71005b11f4ee687b53.setContent(html_7d844e6cb1c23f141269e47c489f62aa);
#
#
#
#         marker_3b779b3ecc24e4a2e55541e876b2f33b.bindPopup(popup_cfa056fea95d3c71005b11f4ee687b53)
#         ;
#
#
#
#
#             var marker_cf707169b84226ecae19a31024d98102 = L.marker(
#                 [33.5356373, 126.8211555],
#                 {}
#             ).addTo(map_c067fe6e874b6f939b6ea184202628dd);
#
#
#         var popup_f04e4c490696cabc12d523e3ce4e9cc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfb88f8d9ea20ca8f89e00359901f85d = $(`&lt;div id=&quot;html_dfb88f8d9ea20ca8f89e00359901f85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;한동올레펜션&lt;/div&gt;`)[0];
#                 popup_f04e4c490696cabc12d523e3ce4e9cc1.setContent(html_dfb88f8d9ea20ca8f89e00359901f85d);
#
#
#
#         marker_cf707169b84226ecae19a31024d98102.bindPopup(popup_f04e4c490696cabc12d523e3ce4e9cc1)
#         ;
#
#
#
#
#             var marker_ff10a7080293f87860fdd4e0b0ede6dd = L.marker(
#                 [33.5172018, 126.8662067],
#                 {}

# %% [markdown]
# ## MarkerCluster

# %%
map = folium.Map(location=[33.41041350000001,126.4913534], zoom_start=10, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
geo_list = []
name_list = []
for i in range(len(df))[:100] :
    lat = df.iloc[i]['위도']
    lng = df.iloc[i]['경도']
    sname = df.iloc[i]['장소명']
    # print(lat, lng, sname)
    geo_list.append( (lat,lng) )
    name_list.append(sname)
    
plugins.MarkerCluster(geo_list, popups=name_list).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa4dc83649ae7b4dab069f03c51c6ea7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa4dc83649ae7b4dab069f03c51c6ea7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa4dc83649ae7b4dab069f03c51c6ea7 = L.map(
#                 &quot;map_aa4dc83649ae7b4dab069f03c51c6ea7&quot;,
#                 {
#                     center: [33.41041350000001, 126.4913534],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_467ba3da542d421f9b6d37df471c7137 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa4dc83649ae7b4dab069f03c51c6ea7);
#
#
#             var marker_cluster_f02b36e36f29efb0c48867557c31947b = L.markerClusterGroup(
#                 {}
#             );
#             map_aa4dc83649ae7b4dab069f03c51c6ea7.addLayer(marker_cluster_f02b36e36f29efb0c48867557c31947b);
#
#
#             var marker_3dca806a2203dd3e340cb98da61f1a15 = L.marker(
#                 [33.2519324, 126.5097695],
#                 {}
#             ).addTo(marker_cluster_f02b36e36f29efb0c48867557c31947b);
#
#
#         var popup_1b07fc53ae42df389fdac304437676d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ed106aa91a142128df187e9d8a726cc = $(`&lt;div id=&quot;html_7ed106aa91a142128df187e9d8a726cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;비스타케이월드컵&lt;/div&gt;`)[0];
#                 popup_1b07fc53ae42df389fdac304437676d1.setContent(html_7ed106aa91a142128df187e9d8a726cc);
#
#
#
#         marker_3dca806a2203dd3e340cb98da61f1a15.bindPopup(popup_1b07fc53ae42df389fdac304437676d1)
#         ;
#
#
#
#
#             var marker_ae1f939488a1ec41c5a22ce0382368d4 = L.marker(
#                 [33.4482999, 126.6376619],
#                 {}
#             ).addTo(marker_cluster_f02b36e36f29efb0c48867557c31947b);
#
#
#         var popup_54ef109486fe818ed16f887d52427449 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbbec4d22693950c5272add5070bc248 = $(`&lt;div id=&quot;html_dbbec4d22693950c5272add5070bc248&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주한화리조트&lt;/div&gt;`)[0];
#                 popup_54ef109486fe818ed16f887d52427449.setContent(html_dbbec4d22693950c5272add5070bc248);
#
#
#
#         marker_ae1f939488a1ec41c5a22ce0382368d4.bindPopup(popup_54ef109486fe818ed16f887d52427449)
#         ;
#
#
#
#
#             var marker_c0b26ce22e7ee4bbd6033915292199eb = L.marker(
#                 [33.2785158, 126.5275284],
#                 {}
#             ).addTo(marker_cluster_f02b36e36f29efb0c48867557c31947b);
#
#
#         var popup_a7162684847422eb2368b085ecdc684c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3af711dfbc9669c228f518866614c44c = $(`&lt;div id=&quot;html_3af711dfbc9669c228f518866614c44c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;비스타케이호텔&lt;/div&gt;`)[0];
#                 popup_a7162684847422eb2368b085ecdc684c.setContent(html_3af711dfbc9669c228f518866614c44c);
#
#
#
#         marker_c0b26ce22e7ee4bbd6033915292199eb.bindPopup(popup_a7162684847422eb2368b085ecdc684c)
#         ;
#
#
#
#
#             var marker_b8e1c44ee03da76c3da554cd79eb9cbf = L.marker(
#                 [33.540343, 126.8262234],
#                 {}
#             ).addTo(marker_cluster_f02b36e36f29efb0c48867557c31947b);
#
#
#         var popup_c568232fb5173c464ef56ab02d45573b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c3000e40490ae821e9a33ff0022f139 = $(`&lt;div id=&quot;html_7c3000e40490ae821e9a33ff0022f139&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;토끼굴 &lt;/div&gt;`)[0];
#                 popup_c568232fb5173c464ef56ab02d45573b.setContent(html_7c3000e40490ae821e9a33ff0022f139);
#
#
#
#         marker_b8e1c44ee03da76c3da554cd79eb9cbf.bindPopup(popup_c568232fb5173c464ef56ab02d45573b)
#         ;
#
#
#
#
#             var marker_48332d29444e73ef4588af069bf69cac = L.marker(
#                 [33.5356373, 126.8211555],
#                 {}
#             ).addTo(marker_cluster_f02b36e36f29efb0c4886755
